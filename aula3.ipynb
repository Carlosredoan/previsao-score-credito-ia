# %%
import pandas as pd

# Passo 1: Importar a base de dados
tabela = pd.read_csv("clientes.csv")

# Passo 2: Visualizar a tabela
display(tabela)

# Passo 3: Verificar quais colunas são texto (object) 
# A IA só entende números, então esse passo é fundamental!
print(tabela.info())
